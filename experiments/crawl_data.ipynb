# %%
import pandas as pd

# %%
meta_data = pd.read_csv("test-data/test-meta-data.csv")

# %%
meta_data.head()
# Out:
#                                                Title     Subtitle  \
# 0  Commission Implementing Decision (EU) 2023/219...  C/2023/6856
# 1  Commission Implementing Decision (EU) 2023/197...  C/2023/6271
# 2  Commission Implementing Decision (EU) 2023/176...  C/2023/6012
# 3  Commission Implementing Decision (EU) 2022/246...  C/2022/9178
# 4  Commission Implementing Decision (EU) 2022/165...  C/2022/6713
#
#   CELEX number  Current consolidated version  Latest consolidated version  \
# 0   32023D2199                           NaN                          NaN
# 1   32023D1978                           NaN                          NaN
# 2   32023D1760                           NaN                          NaN
# 3   32022D2461                           NaN                          NaN
# 4   32022D1657                           NaN                          NaN
#
#    LP_Legal basis                                              ELI  \
# ...

# %%
meta_data["Legal basis"][3]
# Out:
# 'https://eur-lex.europa.eu/legal-content/AUTO/?uri=CELEX:32018L2001'
